# %%
nombre=int(input("ENTREZ UN NOMBRE"))
if nombre > 0:
    print("Le nombre est positif")
if nombre < 0:
    print("Le nombre est négatif")
if nombre == 0:
    print("Le nombre est zéro")

# %%
nom=input("Quel est votre nom ? ")
age=int(input("Quel est votre âge ? "))
if age < 18:
    print("Bonjour", nom, "! Vous êtes mineur.")
else:
    print("Bonjour", nom, "! Vous êtes majeur.")

# %%
nom=input("Quel est votre nom ? ")
age=int(input("Quel est votre âge ? "))
if age < 18:
    statut="mineur"
else:
    statut="majeur"
print("Bonjour", nom, "! Vous êtes", statut + ".")

# %%
nombre=int(input("ENTREZ UN NOMBRE"))
if nombre > 0:
    print("Le nombre est positif")
elif nombre < 0:
    print("Le nombre est négatif")
else:
    print("Le nombre est zéro")

# %%
nombre=int(input("ENTREZ UN NOMBRE"))
print("LA TABLE DE MULTIPLICATION DE", nombre, "EST :")
for i in range(0, 51):
    print(nombre, "x", i, "=", nombre * i)

# %%
liste_nombres=[12, -7, 0, 45, -3, 8]
for nombre in liste_nombres:
    if nombre > 0:
        print(nombre, "est positif")
    elif nombre < 0:
        print(nombre, "est négatif")
    else:
        print(nombre, "est zéro")

# %%
nombre=int(input("ENTREZ UN NOMBRE"))
print("LA TABLE DE MULTIPLICATION DE", nombre, "EST :")
i=0
while i <= 50:
    print(nombre, "x", i, "=", nombre * i)
    i += 1
while 50 <= i :
    print(nombre, "x", i, "=", nombre * i)
    i -= 1

# %%
def addition(a, b):
    print(f"la somme de {a} et {b} est {a + b}")
x, y = int(input("Entrez le premier nombre: ")), int(input("Entrez le deuxième nombre: "))
addition(x, y)

# %%
def addition_fonction(a, b):
    return a + b

x, y = int(input("Entrez le premier nombre: ")), int(input("Entrez le deuxième nombre: "))
somme = addition_fonction(x, y)
print(f"La somme de {x} et {y} est {somme}")
# Out:
# La somme de 12 et -12 est 0

# %% [markdown]
# ---
# # ***[fonction(item for item in liste if condition)]***
# - Élément 1
# - Élément 2
#   - Sous-élément
# * Élément 3
#
# [Google](https://www.google.com)
#
# ![Logo Python](https://www.python.org/static/community_logos/python-logo.png)
# > Ceci est une citation.
# $$
# \int_0^\infty e^{-x} dx = 1
# $$
# ---

# %%
L=[2,5,6,45,89,34,26,90,45,4,7,9,32]
Lsup5=[x for x in L if x>5]
print(Lsup5)
# Out:
# [6, 45, 89, 34, 26, 90, 45, 7, 9, 32]

# %%
B=[]
def fonctionsup5(liste):
    for x in liste:
        if x>5:
            B.append(x)
    return B
print(fonctionsup5(L))
# Out:
# [6, 45, 89, 34, 26, 90, 45, 7, 9, 32]

# %%
Limpair=[x for x in L if x%2!=0]
print(Limpair)
# Out:
# [5, 45, 89, 45, 7, 9]

# %%
def impairdeListe(liste):
    C=[]
    for x in liste:
        if x%2!=0:
            C.append(x)
    return C
print(impairdeListe(L))
# Out:
# [5, 45, 89, 45, 7, 9]

# %%
def compter_serie(terme, i):
    """Compte combien de fois terme[i] se répète consécutivement à partir de i."""
    chiffre = terme[i]
    count = 0
    while i < len(terme) and terme[i] == chiffre:
        count += 1
        i += 1
    return chiffre, count

def terme_suivant(terme):
    """Génère le terme suivant à partir du terme actuel."""
    resultat = ""
    i = 0
    while i < len(terme):
        chiffre, count = compter_serie(terme, i)
        resultat += str(count) + str(chiffre)
        i += count  # on saute toute la série
    return resultat

def conway(n):
    """Retourne le n-ième terme de la suite de Conway (en partant de n=1)."""
    terme = "1"
    for _ in range(n - 1):
        terme = terme_suivant(terme)
    return terme
